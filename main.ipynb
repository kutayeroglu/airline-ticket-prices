# %%
from google.colab import drive
drive_root = '/content/drive'
drive.mount(drive_root)
# Out:
# Mounted at /content/drive

# %%
import sys
import os

project_root = os.path.join(drive_root, 'MyDrive/Colab Notebooks/cmpe540/final-project')
source_root = os.path.join(project_root, 'src')
sys.path.append(source_root)

data_folder_path = os.path.join(project_root, 'data')

# %%
file_name = 'US Airline Flight Routes and Fares 1993-2024.csv'

# %%
from data_ops.loader import load_data
data = load_data(data_folder_path, file_name)
# Out:
# Drive already mounted at /content/drive.
#
# Image file directory: /content/drive/MyDrive/Colab Notebooks/cmpe540/final-project/data
# Does image directory exist? True
# /content/drive/MyDrive/Colab Notebooks/cmpe540/final-project/src/data_ops/loader.py:12: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)

# %%
data
# Out:
#             tbl  Year  quarter  citymarketid_1  citymarketid_2  \
# 0       Table1a  2021        3           30135           33195
# 1       Table1a  2021        3           30135           33195
# 2       Table1a  2021        3           30140           30194
# 3       Table1a  2021        3           30140           30194
# 4       Table1a  2021        3           30140           30466
# ...         ...   ...      ...             ...             ...
# 245950  Table1a  2024        1           35412           31703
# 245951  Table1a  2024        1           35412           32467
# 245952  Table1a  2024        1           35412           32467
# 245953  Table1a  2024        1           35412           33195
# 245954  Table1a  2024        1           35412           33195
#
#                                  city1                                  city2  \
# 0       Allentown/Bethlehem/Easton, PA          Tampa, FL (Metropolitan Area)
# ...
